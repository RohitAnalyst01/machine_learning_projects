# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('Books.csv')
# Out:
# C:\Users\rs083\AppData\Local\Temp\ipykernel_17436\679519066.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('Books.csv')

# %%
books.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271360 entries, 0 to 271359
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 271360 non-null  object
#  1   Book-Title           271360 non-null  object
#  2   Book-Author          271359 non-null  object
#  3   Year-Of-Publication  271360 non-null  object
#  4   Publisher            271358 non-null  object
#  5   Image-URL-S          271360 non-null  object
#  6   Image-URL-M          271360 non-null  object
#  7   Image-URL-L          271357 non-null  object
# dtypes: object(8)
# memory usage: 16.6+ MB

# %%
books = books[['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication']]

# %%
books.shape
# Out:
# (271360, 4)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
for i in books:
  print(books[i].value_counts())
# Out:
# 0195153448    1
# 0746008481    1
# 0395219906    1
# 043916169X    1
# 0879235322    1
#              ..
# 1568303823    1
# 0525947612    1
# 207036819X    1
# 2877306127    1
# 0767409752    1
# Name: ISBN, Length: 271360, dtype: int64
# Selected Poems                                                                                                                    27
# Little Women                                                                                                                      24
# Wuthering Heights                                                                                                                 21
# The Secret Garden                                                                                                                 20
# Dracula                                                                                                                           20
# ...

# %% [markdown]
# Loading and exploring ratings columns

# %%
ratings= pd.read_csv('Ratings.csv')

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
ratings['Book-Rating'].value_counts()
# Out:
# 0     716109
# 8     103736
# 10     78610
# 7      76457
# 9      67541
# 5      50974
# 6      36924
# 4       8904
# 3       5996
# 2       2759
# 1       1770
# Name: Book-Rating, dtype: int64

# %% [markdown]
# Loading users dataset

# %%
users= pd.read_csv('Users.csv')

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
#Merging of dataframes
merged_df = ratings.merge(books,on='ISBN')

# %%
merged_df
# Out:
#          User-ID        ISBN  Book-Rating  \
# 0         276725  034545104X            0
# 1           2313  034545104X            5
# 2           6543  034545104X            0
# 3           8680  034545104X            5
# 4          10314  034545104X            9
# ...          ...         ...          ...
# 1031131   276688  0517145553            0
# 1031132   276688  1575660792            7
# 1031133   276690  0590907301            0
# 1031134   276704  0679752714            0
# 1031135   276704  0806917695            5
#
#                                                 Book-Title      Book-Author  \
# 0                                     Flesh Tones: A Novel       M. J. Rose
# 1                                     Flesh Tones: A Novel       M. J. Rose
# 2                                     Flesh Tones: A Novel       M. J. Rose
# 3                                     Flesh Tones: A Novel       M. J. Rose
# ...

# %%
#Collaborative recc sys
#grouping the titles according to ratings
num_rating = merged_df.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating.rename(columns={'Book-Rating' : 'num_rating'},inplace=True)

# %%
num_rating
# Out:
#                                                Book-Title  num_rating
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
# [241071 rows x 2 columns]

# %%
avg_rating = merged_df.groupby('Book-Title').count()['Book-Rating'].reset_index()
avg_rating.rename(columns={'Book-Rating' : 'avg_rating'},inplace=True)

# %%
avg_rating
# Out:
#                                                Book-Title  avg_rating
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
# [241071 rows x 2 columns]

# %%
dataframe = num_rating.merge(avg_rating,on='Book-Title')

# %%
dataframe
# Out:
#                                                Book-Title  num_rating  \
# 0        A Light in the Storm: The Civil War Diary of ...           4
# 1                                   Always Have Popsicles           1
# 2                    Apple Magic (The Collector's series)           1
# 3        Ask Lily (Young Women of Faith: Lily Series, ...           1
# 4        Beyond IBM: Leadership Marketing and Finance ...           1
# ...                                                   ...         ...
# 241066                                      Ã?Â?lpiraten.           2
# 241067                     Ã?Â?rger mit Produkt X. Roman.           4
# 241068                                Ã?Â?sterlich leben.           1
# 241069                              Ã?Â?stlich der Berge.           3
# 241070                                  Ã?Â?thique en toc           2
#
#         avg_rating
# 0                4
# 1                1
# 2                1
# 3                1
# 4                1
# ...

# %%
popular_books = dataframe[dataframe['avg_rating']>=200].sort_values('avg_rating',ascending=False).head(20)

# %%
popular_books
# Out:
#                                                Book-Title  num_rating  \
# 234951                                        Wild Animus        2502
# 196326                          The Lovely Bones: A Novel        1295
# 183573                                  The Da Vinci Code         898
# 5303                                      A Painted House         838
# 199237                         The Nanny Diaries: A Novel         828
# 27922                               Bridget Jones's Diary         815
# 206502                            The Secret Life of Bees         774
# 52983     Divine Secrets of the Ya-Ya Sisterhood: A Novel         740
# 204387                The Red Tent (Bestselling Backlist)         723
# 14392                                 Angels &amp; Demons         670
# 107962                                         Life of Pi         664
# 162651                             Snow Falling on Cedars         662
# ...

# %%
popular_books =  popular_books.merge(books,on='Book-Title').drop_duplicates('Book-Title')

# %%
books.columns
# Out:
# Index(['ISBN', 'Book-Title', 'Book-Author', 'Year-Of-Publication'], dtype='object')

# %%
c = merged_df.groupby('User-ID').count()['Book-Rating']>200
actual_readers = c[c]

# %%
readers = merged_df[merged_df['User-ID'].isin(actual_readers)]

# %%
readers.shape
# Out:
# (0, 6)

# %%
m = merged_df.groupby('Book-Title').count()['Book-Rating']>=50
books_popular = m[m]

# %%
real_rating = merged_df[merged_df['Book-Rating'].isin(books_popular)]

# %%
pivot = real_rating.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pivot
# Out:
# User-ID                                             1314    1548    1674    \
# Book-Title
#  Earth Prayers From around the World: 365 Praye...     NaN     NaN     NaN
# 10,000 Dreams Interpreted or What's in a Dream         NaN     NaN     NaN
# 1848: The Revolutionary Tide in Europe (Revolut...     NaN     NaN     NaN
# 20,000 Leagues Under the Sea                           NaN     NaN     NaN
# 4 Blondes                                              NaN     NaN     NaN
# ...                                                    ...     ...     ...
# Ziggy Treasury Pb                                      NaN     NaN     NaN
# Zirkusbriefe von Felix. Ein kleiner Hase unterw...     NaN     NaN     NaN
# Zwei Frauen.                                           NaN     NaN     NaN
# Zzzzzzzz-- (MÃ­nima de butxaca)                        NaN     NaN     NaN
# schwimmen gegen blond                                  NaN     NaN     NaN
#
# ...

# %%
pivot.fillna(0,inplace=True)

# %%
pivot
# Out:
# User-ID                                             1314    1548    1674    \
# Book-Title
#  Earth Prayers From around the World: 365 Praye...     0.0     0.0     0.0
# 10,000 Dreams Interpreted or What's in a Dream         0.0     0.0     0.0
# 1848: The Revolutionary Tide in Europe (Revolut...     0.0     0.0     0.0
# 20,000 Leagues Under the Sea                           0.0     0.0     0.0
# 4 Blondes                                              0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Ziggy Treasury Pb                                      0.0     0.0     0.0
# Zirkusbriefe von Felix. Ein kleiner Hase unterw...     0.0     0.0     0.0
# Zwei Frauen.                                           0.0     0.0     0.0
# Zzzzzzzz-- (MÃ­nima de butxaca)                        0.0     0.0     0.0
# schwimmen gegen blond                                  0.0     0.0     0.0
#
# ...

# %%
from scipy.sparse import csr_matrix
book_sparse = csr_matrix(pivot)

# %%
from sklearn.neighbors import NearestNeighbors
model = NearestNeighbors(algorithm='brute')
model.fit(book_sparse)
# Out:
# NearestNeighbors(algorithm='brute')

# %%
distances, suggestions = model.kneighbors(pivot.iloc[237, :].values.reshape(1, -1))

# %%
for i in range(len(suggestions)):
  print(pivot.index[suggestions[i]])
# Out:
# Index(['Jackdaws', 'The Smoke Jumper',
#        'Pemberley or Pride and Prejudice Continued', 'Bloodlines',
#        'L'Homme qui murmurait Ã?Â  l'oreille des chevaux'],
#       dtype='object', name='Book-Title')

# %%
np.where(pivot.index=='Animal Farm')[0][0]
# Out:
# 73

# %%
def recommend_book(Book_title):
    book_id=np.where(pivot.index=='Animal Farm')[0][0]
    distances,suggestions=model.kneighbors(pivot.iloc[book_id,:].values.reshape(1,-1),n_neighbors=6)

    x=[]
    
    for i in range(len(suggestions)):
        for j in pivot.index[suggestions[i]]:
            x.append(j)
            
    
    y=[]
  
    for i in range(1,len(x)):
        print(x[i])

# %%
recommend_book('Animal Farm')
# Out:
# Small Town
# Smoked: A True Story About the Kids Next Door
# Small Miracles: Extraordinary Coincidences from Everyday Life
# Slave to Fashion : A Novel
# Snow Baby (9 Months Later) (Superromance, 939)
